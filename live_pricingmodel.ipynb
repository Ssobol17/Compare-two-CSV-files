# %% [markdown]
# <a href="https://colab.research.google.com/github/Ssobol17/Compare-two-CSV-files/blob/master/live_pricingmodel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#compare live pricing

# %%
from bs4 import BeautifulSoup
import requests
import time

# %%
#Get URl that contain price
url= 'https://www.google.com/search?q=Bitcoin+price'

#make request

HTML = requests.get(url)

#parse HTMl

soup= BeautifulSoup(HTML.text, 'html.parser')

#print soup that show price of currency
print(soup.prettify())

# %%
#<div class="BNeawe iBp4i AP7Wnd">

#Create a Function to get price

def get_crypto_price(coin):
  #Get URl that contain price
  url= 'https://www.google.com/search?q='+coin+'+price'

  #make request

  HTML = requests.get(url)

  #parse HTMl

  soup= BeautifulSoup(HTML.text, 'html.parser')

  #print soup that show price of currency
  print(soup.prettify())

  #find current price
  text = soup.find('div', attrs={'class':'BNeawe iBp4i AP7Wnd'}).find('div', attrs={'class': 'BNeawe iBp4i AP7Wnd'}).text

#return text
  return text

# %%
#get price of a coin
price = get_crypto_price('bitcoin')

print(price)
# Out:
# <!DOCTYPE doctype html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"/>
#   <title>
#    bitcoin price - Google Search
#   </title>
#   <script nonce="xioh93+plCaiOmmRw+eqGw==">
#    (function(){
# document.documentElement.addEventListener("submit",function(b){var a;if(a=b.target){var c=a.getAttribute("data-submitfalse");a="1"==c||"q"==c&&!a.elements.q.value?!0:!1}else a=!1;a&&(b.preventDefault(),b.stopPropagation())},!0);document.documentElement.addEventListener("click",function(b){var a;a:{for(a=b.target;a&&a!=document.documentElement;a=a.parentElement)if("A"==a.tagName){a="1"==a.getAttribute("data-nohref");break a}a=!1}a&&b.preventDefault()},!0);}).call(this);(function(){
# ...

# %%
#function to consistanly show rpice when it changes
def main():
  last_price = -1
  #create a loop show price
  while True:
    #choose the coin
    crypto = 'bitcoin'
    #get currency
    price = get_crypto_price(crypto)
    #check if change
    if price != last_price:
      print(crypto+ 'price:', price)
      last_price = price
      time.sleep(3)

# %%
#run execute main function
main()
# Out:
# Streaming output truncated to the last 5000 lines.
#        <h3 class="zBAuLc">
#         <div class="BNeawe vvjwJb AP7Wnd">
#          Bitcoin Price Chart Today - Live BTC/USD - Gold Price
#         </div>
#        </h3>
#        <div class="BNeawe UPmit AP7Wnd">
#         goldprice.org › cryptocurrency-price › bitcoin-price
#        </div>
#       </a>
#      </div>
#      <div class="x54gtf">
#      </div>
#      <div class="kCrYT">
#       <div>
#        <div class="BNeawe s3v9rd AP7Wnd">
#         <div>
#          <div>
#           <div class="BNeawe s3v9rd AP7Wnd">
#            View Bitcoin (BTC) price charts in USD and other currencies including real time and historical prices, technical indicators, analysis tools, and other ...
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div>
#     <div class="ZINbbc xpd O9g5cc uUPGi">
#      <div class="kCrYT">
# ...
